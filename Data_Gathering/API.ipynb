# %% [markdown]
# ## API

# %%
import pandas as pd

# %%
import requests
request = requests.get('https://api.github.com/repos/pandas-dev/pandas/issues')
request.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/66004',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/66004/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/66004/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/66004/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/66004',
#   'id': 4729585506,
#   'node_id': 'PR_kwDOAA0YD87p1nGD',
#   'number': 66004,
#   'title': 'BUG: DataFrame repr honors display.width with max_columns=0 (GH#21337)',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
# ...

# %%
df= pd.DataFrame(request.json(), columns=['id', 'title', 'state', 'created_at', 'updated_at', 'closed_at', 'user'])

# %%
df
# Out:
#             id                                              title state  \
# 0   4729585506  BUG: DataFrame repr honors display.width with ...  open
# 1   4729585306  BUG: DataFrame constructor with a list-like da...  open
# 2   4729532619  TST: pd.NA preserved through Series.map for nu...  open
# 3   4729531153  BUG: DataFrame.__setitem__ silently dropping c...  open
# 4   4729524683  BUG: DataFrame constructor aliases index and c...  open
# 5   4729436686  TST: replace does not coerce np.nan to NaT (GH...  open
# 6   4729416659  TST: cut Series with NaN and integer bins (GH#...  open
# 7   4729415088  TST: tz-aware grouper/map returning tz-naive (...  open
# 8   4729410681  DOC: document CSV round-trip limitation with M...  open
# 9   4729401209  TST: to_csv does not require escapechar for nu...  open
# 10  4729383250  BUG: prevent silent corruption of Index via .v...  open
# 11  4729353252  BUG: bar/barh plot raises on timedelta64 data ...  open
# ...
