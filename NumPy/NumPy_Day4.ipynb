# %% [markdown]
# # 3D plotting

# %%
import numpy as np
import pandas as pd

a = np.linspace(-10, 9, 21, dtype=int)
b = np.linspace(-10, 9, 21, dtype=int)

xx, yy = np.meshgrid(a, b)

print(xx)

# %% [markdown]
# - Plotting 3D graphs
# - meshgrid

# %%
import matplotlib.pyplot as plt
plt.scatter(xx,yy)

# %%
def fun(x,y):
    return 3*np.sin(x) + 2*y
zz=fun(xx,yy)

# %%
# import 3D library
import plotly.express as px
import plotly.graph_objects as go

# %%
fig = px.scatter_3d()

fig.add_trace(go.Surface(x=xx,y=yy,z=zz))

fig.show()

# %% [markdown]
# ### Working with random

# %%
# random
# randint
# seed
# choice

# %%
# np.random.seed(0)

# %%
np.random.seed(0)
x=np.random.random((2,3))
x
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338],
#        [0.54488318, 0.4236548 , 0.64589411]])

# %%
np.random.seed(0)
np.random.randint(1,100,12).reshape(3,4)
# Out:
# array([[45, 48, 65, 68],
#        [68, 10, 84, 22],
#        [37, 88, 71, 89]], dtype=int32)

# %% [markdown]
# - Suffle array()

# %%
a=np.array=([12,14,15,14,34,3,2,])

# %%
np.random.shuffle(a)
a
# Out:
# [2, 14, 3, 14, 15, 34, 12]

# %%
np.random.choice(a,3)
# Out:
# array([12,  2, 14])

# %% [markdown]
# ### Working with images

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img = cv2.imread('broadcasting-rules.png')

# image show
plt.imshow(img)

# %%
# flip()
flip_img=np.flip(img)
plt.imshow(flip_img)

# %%
# clip()
plt.imshow(np.clip(img,8,200))

# %%
plt.imshow(255-img)

# %%
plt.imshow(img[100:500,100:900,:])

# %%
# Plot Histogram() flatten is use to convert 2d array to 3d array
plt.hist(img.flatten(),bins=255)
# Out:
# (array([3.00000e+00, 0.00000e+00, 9.00000e+00, 3.30000e+01, 5.10000e+01,
#         1.86000e+02, 5.10000e+01, 5.10000e+01, 1.20000e+01, 1.20000e+01,
#         2.40000e+01, 1.20000e+01, 9.00000e+00, 3.00000e+00, 8.00000e+00,
#         1.40000e+01, 7.00000e+00, 1.00000e+00, 1.80000e+01, 9.00000e+00,
#         3.90000e+01, 1.14000e+02, 2.19000e+02, 5.16000e+02, 2.25000e+02,
#         2.40000e+01, 1.20000e+01, 2.70000e+01, 2.40000e+01, 9.00000e+00,
#         9.00000e+00, 2.10000e+01, 6.00000e+00, 1.80000e+01, 1.20000e+01,
#         1.20000e+01, 0.00000e+00, 3.90000e+01, 1.98000e+02, 4.83000e+02,
#         4.44000e+02, 9.30000e+02, 1.59000e+02, 1.08000e+02, 3.90000e+01,
#         4.50000e+01, 1.05000e+02, 1.73000e+02, 5.91000e+02, 1.23700e+03,
#         1.37500e+03, 1.18600e+03, 1.42800e+03, 4.00000e+02, 1.32000e+02,
#         2.81000e+02, 1.11000e+02, 6.40000e+01, 9.60000e+01, 4.50000e+01,
#         135.37647059, 136.34901961, 137.32156863, 138.29411765,
#         139.26666667, 140.23921569, 141.21176471, 142.18431373,
#         143.15686275, 144.12941176, 145.10196078, 146.0745098 ,
#         147.04705882, 148.01960784, 148.99215686, 149.96470588,
#         150.9372549 , 151.90980392, 152.88235294, 153.85490196,
#         154.82745098, 155.8       , 156.77254902, 157.74509804,
#         158.71764706, 159.69019608, 160.6627451 , 161.63529412,
#         162.60784314, 163.58039216, 164.55294118, 165.5254902 ,
#         166.49803922, 167.47058824, 168.44313725, 169.41568627,
#         170.38823529, 171.36078431, 172.33333333, 173.30588235,
#         174.27843137, 175.25098039, 176.22352941, 177.19607843,
#         178.16862745, 179.14117647, 180.11372549, 181.08627451,
#         182.05882353, 183.03137255, 184.00392157, 184.97647059,
#         185.94901961, 186.92156863, 187.89411765, 188.86666667,
#         189.83921569, 190.81176471, 191.78431373, 192.75686275,
#         193.72941176, 194.70196078, 195.6745098 , 196.64705882,
#         197.61960784, 198.59215686, 199.56470588, 200.5372549 ,
#         201.50980392, 202.48235294, 203.45490196, 204.42745098,
#         205.4       , 206.37254902, 207.34509804, 208.31764706,
#         209.29019608, 210.2627451 , 211.23529412, 212.20784314,
#         213.18039216, 214.15294118, 215.1254902 , 216.09803922,
#         217.07058824, 218.04313725, 219.01568627, 219.98823529,
#         220.96078431, 221.93333333, 222.90588235, 223.87843137,
#         224.85098039, 225.82352941, 226.79607843, 227.76862745,
#         228.74117647, 229.71372549, 230.68627451, 231.65882353,
#         232.63137255, 233.60392157, 234.57647059, 235.54901961,
#         236.52156863, 237.49411765, 238.46666667, 239.43921569,
#         240.41176471, 241.38431373, 242.35686275, 243.32941176,
#         244.30196078, 245.2745098 , 246.24705882, 247.21960784,
#         248.19215686, 249.16470588, 250.1372549 , 251.10980392,
#         252.08235294, 253.05490196, 254.02745098, 255.        ]),
#  <BarContainer object of 255 artists>)

# %% [markdown]
# ### Sturctured arrays

# %%
a=np.array([10,'Helo',True,1.5])

# %%
# name iq cgpa placed
dt=np.dtype(
    [
        ('name','U20'),
        ('iq',np.int32),
        ('cgpa', np.float16),
        ('placed','U20')
    ]
)

# %%
stu=np.array(
    [
        ('Amit',100,7.8,'Y'),
        ('Aditya',100,7.8,'Y'),
        ('Shivam',100,7.8,'Y')
    ],dtype=dt
)
stu
# Out:
# array([('Amit', 100, 7.8, 'Y'), ('Aditya', 100, 7.8, 'Y'),
#        ('Shivam', 100, 7.8, 'Y')],
#       dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f2'), ('placed', '<U20')])

# %% [markdown]
# ### save and load numpy array

# %%
np.save('student.npy',stu)

# %%
a=np.load('student.npy')
a[0]
# Out:
# np.void(('Amit', 100, 7.8, 'Y'), dtype=[('name', '<U20'), ('iq', '<i4'), ('cgpa', '<f2'), ('placed', '<U20')])
